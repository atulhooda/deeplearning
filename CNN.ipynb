# %% [markdown]
# Importing the libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Part 1 - Data Preprocessing

# %%
import os

print("Current folder:", os.getcwd())
print("CNN notebook sees these folders:")
print(os.listdir())
# Out:
# Current folder: /Users/atulhooda/coding/deep learning
# CNN notebook sees these folders:
# ['tensorflow-env', 'ANN.ipynb', 'CNN.ipynb', 'README.md', '.gitignore', '.venv', '.git', 'Deep Learning A-Z']

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

training_set = train_datagen.flow_from_directory(
    'Deep Learning A-Z/Part 2 - Convolutional Neural Networks (CNN)/dataset/training_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)


# Preprocessing the Test set

test_datagen = ImageDataGenerator(
    rescale=1./255
)

test_set = test_datagen.flow_from_directory(
    'Deep Learning A-Z/Part 2 - Convolutional Neural Networks (CNN)/dataset/test_set',
    target_size=(64, 64),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# # Part 2 - Building the CNN

# %%
cnn = tf.keras.models.Sequential()

# %%
#adding the convolution layer
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3,activation='relu',input_shape = [64,64,3]))
# Out:
# /Users/atulhooda/coding/deep learning/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#max pooling
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
#flatenning
cnn.add(tf.keras.layers.Flatten())

# %%
#full connection
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %%
#output
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Training the CNN

# %%
#compiling the CNN
cnn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### training the CNN on training set and evaluating it on

# %%
cnn.fit(x=training_set, validation_data=test_set, epochs=25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.5560 - loss: 0.6880 - val_accuracy: 0.5755 - val_loss: 0.6664
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.6736 - loss: 0.6118 - val_accuracy: 0.7080 - val_loss: 0.5642
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.7154 - loss: 0.5558 - val_accuracy: 0.7340 - val_loss: 0.5309
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7369 - loss: 0.5248 - val_accuracy: 0.7600 - val_loss: 0.4973
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7519 - loss: 0.5026 - val_accuracy: 0.6970 - val_loss: 0.5951
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7645 - loss: 0.4829 - val_accuracy: 0.7430 - val_loss: 0.5265
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7740 - loss: 0.4662 - val_accuracy: 0.7995 - val_loss: 0.4496
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7883 - loss: 0.4506 - val_accuracy: 0.8005 - val_loss: 0.4460
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7935 - loss: 0.4394 - val_accuracy: 0.7835 - val_loss: 0.4582
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8024 - loss: 0.4243 - val_accuracy: 0.8005 - val_loss: 0.4440
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8001 - loss: 0.4223 - val_accuracy: 0.8070 - val_loss: 0.4239
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8102 - loss: 0.4107 - val_accuracy: 0.8045 - val_loss: 0.4335
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8240 - loss: 0.3907 - val_accuracy: 0.8050 - val_loss: 0.4437
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.8205 - loss: 0.3875 - val_accuracy: 0.7860 - val_loss: 0.4502
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8306 - loss: 0.3754 - val_accuracy: 0.8080 - val_loss: 0.4259
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8397 - loss: 0.3617 - val_accuracy: 0.8050 - val_loss: 0.4204
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 27ms/step - accuracy: 0.8407 - loss: 0.3521 - val_accuracy: 0.7965 - val_loss: 0.4644
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8494 - loss: 0.3423 - val_accuracy: 0.8025 - val_loss: 0.4519
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8487 - loss: 0.3295 - val_accuracy: 0.8230 - val_loss: 0.4095
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8526 - loss: 0.3313 - val_accuracy: 0.8105 - val_loss: 0.4477
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8611 - loss: 0.3145 - val_accuracy: 0.8185 - val_loss: 0.4134
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8701 - loss: 0.2955 - val_accuracy: 0.8030 - val_loss: 0.4638
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8708 - loss: 0.2926 - val_accuracy: 0.7980 - val_loss: 0.4713
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8727 - loss: 0.2900 - val_accuracy: 0.8080 - val_loss: 0.4678
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.8752 - loss: 0.2882 - val_accuracy: 0.8145 - val_loss: 0.4519

# %% [markdown]
# # part 4 : making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Deep Learning A-Z/Part 2 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_1.jpg', target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
print(prediction)
# Out:
# dog

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Deep Learning A-Z/Part 2 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_2.jpg', target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
    
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# cat

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Deep Learning A-Z/Part 2 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_3.jpg', target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
    
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# dog

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('Deep Learning A-Z/Part 2 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_4.jpg', target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis=0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'
    
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# dog

# %%
import numpy as np
from keras.preprocessing import image

# Load the image
test_image = image.load_img(
    'Deep Learning A-Z/Part 2 - Convolutional Neural Networks (CNN)/dataset/single_prediction/cat_or_dog_4.jpg',
    target_size=(64, 64)
)

# Convert image to array
test_image = image.img_to_array(test_image)

# Rescale (only if you used rescale=1./255 during training)
test_image = test_image / 255.0

# Add batch dimension
test_image = np.expand_dims(test_image, axis=0)

# Predict
result = cnn.predict(test_image)

# Print probability
print("Prediction Probability:", result)

# Print class mapping
print(training_set.class_indices)

# Make prediction
if result[0][0] > 0.5:
    prediction = "dog"
else:
    prediction = "cat"

print("Predicted Class:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Prediction Probability: [[0.4179999]]
# {'cats': 0, 'dogs': 1}
# Predicted Class: cat
